# %%
# %load_ext autoreload
# %autoreload 2
# !pwd
# !hostname
# Out:
# /home/ajasja/projects/truncator
# dig1

# %%
import numpy
import numpy as np

from glob import glob
import os

import truncator

import pymol
from pymol import cmd
import pandas as pd

# %%
truncator.cut_bundles(struct_name='data/ZCON_37_3+1.pdb', out_dir='testing_out/', num_heptads=4)
# Out:
#  PyMOL not running, entering library mode (experimental)
# testing_out//ZCON_37_3+1__numH4__from-22.25__to17.45.pdb :  byres (name ca and ss H and z>-22.25 and z<17.45)
# testing_out//ZCON_37_3+1__numH4__from-20.07__to19.63.pdb :  byres (name ca and ss H and z>-20.07 and z<19.63)
# testing_out//ZCON_37_3+1__numH4__from-17.89__to21.81.pdb :  byres (name ca and ss H and z>-17.89 and z<21.81)
# ['testing_out//ZCON_37_3+1__numH4__from-22.25__to17.45.pdb',
#  'testing_out//ZCON_37_3+1__numH4__from-20.07__to19.63.pdb',
#  'testing_out//ZCON_37_3+1__numH4__from-17.89__to21.81.pdb']

# %%
truncator.regroup_chains("testing_out//ZCON_37_3+1__numH4__from-22.25__to17.45.pdb", "testing_out/grouped",
                        new_chain_A="AB", new_chain_B="CD")
# Out:
# saving chain A
# saving chain B
# saving chain C
# saving chain D
# testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.pdb
# 'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.pdb'

# %%
truncator.regroup_chains("testing_out//ZCON_37_3+1__numH4__from-22.25__to17.45.pdb", "testing_out/grouped",
                        new_chain_A="C", new_chain_B="ABD", save_segi="True")
# Out:
# saving chain A
# saving chain B
# saving chain C
# saving chain D
# testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.pdb
# 'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.pdb'

# %%
truncator.regroup_chains("testing_out//ZCON_37_3+1__numH4__from-22.25__to17.45.pdb", "testing_out/grouped",
                        new_chain_A="C", new_chain_B="ABD", save_segi=False,
                        out_name="testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.pdb")
# Out:
# testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.pdb
# 'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.pdb'

# %%
#cmd.load("testing_out//ZCON_37_3+1__numH4__from-22.25__to17.45.pdb")
#m = cmd.get_model("chain A")

# %%
pdb_files = glob("testing_out/grouped/*.pdb")
pdb_files
# Out:
# ['testing_out/grouped/ZCON_37_N3_C1_2.pdb',
#  'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.pdb',
#  'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.pdb',
#  'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.pdb']

# %%
# %%time
sf= []
for pdb in pdb_files:
    sf.append(truncator.score_interface(pdb,
                    script_name="truncator/xml/03_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_quick_no_holes.xml",
                    out_dir="testing_out/grouped/scoring", test_run=False))
sf
# Out:
# /software/rosetta/latest/bin/rosetta_scripts     -out:file:o  testing_out/grouped/scoring/ZCON_37_N3_C1_2.pdb     -out:file:scorefile  testing_out/grouped/scoring/ZCON_37_N3_C1_2.sc       -parser:protocol truncator/xml/03_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_quick_no_holes.xml -s testing_out/grouped/ZCON_37_N3_C1_2.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:file:scorefile_format json     -holes:dalphaball truncator/scripts/DAlphaBall.gcc -out:no_nstruct_label     > testing_out/grouped/scoring/ZCON_37_N3_C1_2.log
# /home/ajasja/.conda/envs/pyro_scripts/lib/python3.6/site-packages/pandas/core/frame.py:6336: FutureWarning: 'decoy' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   rsuffix=rsuffix, sort=sort)
# Saving to: testing_out/grouped/scoring/ZCON_37_N3_C1_2_IA.sc
# /software/rosetta/latest/bin/rosetta_scripts     -out:file:o  testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.pdb     -out:file:scorefile  testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.sc       -parser:protocol truncator/xml/03_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_quick_no_holes.xml -s testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:file:scorefile_format json     -holes:dalphaball truncator/scripts/DAlphaBall.gcc -out:no_nstruct_label     > testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.log
# /home/ajasja/.conda/envs/pyro_scripts/lib/python3.6/site-packages/pandas/core/frame.py:6336: FutureWarning: 'decoy' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   rsuffix=rsuffix, sort=sort)
# Saving to: testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD_IA.sc
# /software/rosetta/latest/bin/rosetta_scripts     -out:file:o  testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.pdb     -out:file:scorefile  testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.sc       -parser:protocol truncator/xml/03_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_quick_no_holes.xml -s testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:file:scorefile_format json     -holes:dalphaball truncator/scripts/DAlphaBall.gcc -out:no_nstruct_label     > testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.log
# /home/ajasja/.conda/envs/pyro_scripts/lib/python3.6/site-packages/pandas/core/frame.py:6336: FutureWarning: 'decoy' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   rsuffix=rsuffix, sort=sort)
# Saving to: testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi_IA.sc
# /software/rosetta/latest/bin/rosetta_scripts     -out:file:o  testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.pdb     -out:file:scorefile  testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.sc       -parser:protocol truncator/xml/03_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_quick_no_holes.xml -s testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:file:scorefile_format json     -holes:dalphaball truncator/scripts/DAlphaBall.gcc -out:no_nstruct_label     > testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.log
# Saving to: testing_out/grouped/scoring/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD_IA.sc
# CPU times: user 900 ms, sys: 25.9 ms, total: 925 ms
# Wall time: 4min 41s
# /home/ajasja/.conda/envs/pyro_scripts/lib/python3.6/site-packages/pandas/core/frame.py:6336: FutureWarning: 'decoy' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   rsuffix=rsuffix, sort=sort)

# %%
import truncator
score_files = sorted(glob("testing_out/grouped/*_IA.sc"))
score_files
# Out:
# ['testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD_IA.sc',
#  'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi_IA.sc',
#  'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD_IA.sc',
#  'testing_out/grouped/ZCON_37_N3_C1_2_IA.sc']

# %%
scores = truncator.read_score_files(score_files, skiprows=False, load_seq=False).set_index('decoy')
with pd.option_context("display.max_rows", 1000, "display.max_colwidth", 80, "display.width", 50):
    display(scores.transpose())
# Out:
#    NetCharge_A  NetCharge_B  VirtualRootMover_root  average_res_energy_IA  \
# 0            5            0                    109               -3.13841
#
#    cavity_volume  complex_normalized  cross_interface_energy_IA  \
# 0       10.27929            -2.88429                  -0.043042
#
#    cross_interface_hbonds_IA    dG_cross  dG_cross/dSASAx100  ...   \
# 0                         13 -114.047081           -4.304254  ...
#
#    total_sasa_IA  total_sasa_hydrophobic_A  total_sasa_hydrophobic_AB  \
# 0        6709.97               2850.500488                3830.436279
#
#    total_sasa_hydrophobic_B  total_sasa_polar_A  total_sasa_polar_AB  \
# 0               2961.187988         1877.889282           2953.42627
#
#    total_sasa_polar_B  total_score  uhb  uhb2
# 0         1743.921387  -311.503281    0     0
#
# [1 rows x 92 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-5847918917ac> in <module>()
# ----> 1 scores = truncator.read_score_files(score_files, skiprows=False, load_seq=False).set_index('decoy')
#       2 with pd.option_context("display.max_rows", 1000, "display.max_colwidth", 80, "display.width", 50):
#       3     display(scores.transpose())
#
# ~/projects/truncator/truncator/utils.py in read_score_files(file_names, pdb_dir, verbose, load_seq, skiprows)
#     244     dfs = []
#     245     for file_name in file_names:
# --> 246         dfs.append(read_score_file(file_name, pdb_dir=pdb_dir, verbose=verbose, load_seq=load_seq, skiprows=skiprows))
#     247     dfs = pd.concat(dfs, sort=False)
#     248
#
# ~/projects/truncator/truncator/utils.py in read_score_file(file_name, pdb_dir, verbose, load_seq, skiprows)
#     226     #MWs = []
#     227     print(df)
# --> 228     for n, name in enumerate(df.decoy.values):
#     229         if verbose:
#     230             print(name)
#
# ~/.conda/envs/pyro_scripts/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'decoy'

# %%
score
# Out:
#    SCORE:  total_score  NetCharge_A NetCharge_B VirtualRootMover_root  \
# 0  SCORE:     -360.706         -3.0      -6.000               120.000
# 1  SCORE:     -360.706          2.0           -6.000           -3.000
#
#   cart_bonded_monomer cavity_volume  complex_normalized  dG_cross  \
# 0               0.000         0.000              -3.031  -102.183
# 1                 675.431  2664.716               1.340     0.000
#
#    dG_cross/dSASAx100  dG_separated  dG_separated/dSASAx100       ...         \
# 0               -3.98       -93.888                  -3.657       ...
# 1                0.00        -3.031                  32.000       ...
#
#    Unnamed: 106  Unnamed: 107 Unnamed: 108  Unnamed: 109 Unnamed: 110  \
# 0           NaN           NaN          NaN           NaN          NaN
# 1           0.0         0.896          1.0       -48.399          0.0
#
#    Unnamed: 111  Unnamed: 112 Unnamed: 113  Unnamed: 114     Unnamed: 115
# 0           NaN           NaN          NaN           NaN              NaN
# 1           3.0           1.0          1.0           0.0  ZCON_37_N3_C1_2
#
# [2 rows x 116 columns]

# %%
# Out:
# /software/rosetta/latest/bin/rosetta_scripts     -parser:protocol truncator/xml/04_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_select.xml -s testing_out/grouped/ZCON_37_N3_C1_2.pdb     -out:file:scorefile  testing_out/grouped/ZCON_37_N3_C1_2.sc     -out:file:o  testing_out/grouped/ZCON_37_N3_C1_2.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:no_nstruct_label     -holes:dalphaball truncator/scripts/DAlphaBall.gcc     > testing_out/grouped/ZCON_37_N3_C1_2.log
# testing_out/grouped/ZCON_37_N3_C1_2.sc
# Saving to: testing_out/grouped/ZCON_37_N3_C1_2_IA.sc
# /software/rosetta/latest/bin/rosetta_scripts     -parser:protocol truncator/xml/04_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_select.xml -s testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.pdb     -out:file:scorefile  testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.sc     -out:file:o  testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:no_nstruct_label     -holes:dalphaball truncator/scripts/DAlphaBall.gcc     > testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.log
# testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.sc
# Saving to: testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD_IA.sc
# /software/rosetta/latest/bin/rosetta_scripts     -parser:protocol truncator/xml/04_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_select.xml -s testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.pdb     -out:file:scorefile  testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.sc     -out:file:o  testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:no_nstruct_label     -holes:dalphaball truncator/scripts/DAlphaBall.gcc     > testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.log
# testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi.sc
# Saving to: testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi_IA.sc
# /software/rosetta/latest/bin/rosetta_scripts     -parser:protocol truncator/xml/04_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_select.xml -s testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.pdb     -out:file:scorefile  testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.sc     -out:file:o  testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:no_nstruct_label     -holes:dalphaball truncator/scripts/DAlphaBall.gcc     > testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.log
# testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.sc
# Saving to: testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD_IA.sc
# CPU times: user 119 ms, sys: 31 ms, total: 150 ms
# Wall time: 3min 18s

# %%
files = sorted(glob("testing_out/grouped/*_IA*.sc"), reverse=True)
files
# Out:
# ['testing_out/grouped/ZCON_37_N3_C1_2_IA.sc',
#  'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD_IA.sc',
#  'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi_IA.sc',
#  'testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD_IA.sc']

# %%
# Out:
# description                                                                                    ZCON_37_N3_C1_2  \
# total_score                                                                                           -360.706
# AlaCount                                                                                                     2
# NetCharge_binder                                                                                            -6
# NetCharge_target                                                                                            -3
# buried_minus_exposed                                                                                   675.431
# buried_np                                                                                              2664.72
# buried_over_exposed                                                                                       1.34
# cart_bonded_monomer                                                                                          0
# cavity_volume                                                                                                0
# complex_normalized                                                                                      -3.031
# contact_all                                                                                                 32
# contact_core_SASA                                                                                           32
# contact_core_SCN                                                                                            32
# dG_cross                                                                                              -102.183
# dG_cross/dSASAx100                                                                                       -3.98
# dG_separated                                                                                           -93.888
# dG_separated/dSASAx100                                                                                  -3.657
# dSASA_hphobic                                                                                          1976.47
# dSASA_int                                                                                              2567.33
# dSASA_polar                                                                                             590.86
# degree                                                                                                   8.143
# degree_core_SASA                                                                                         8.143
# degree_core_SCN                                                                                          8.143
# delta_unsatHbonds                                                                                            5
# des_res_chA                                                                                                 34
# des_res_chB                                                                                                 34
# dslf_fa13                                                                                                    0
# dslf_fa13_monomer                                                                                            0
# dslf_quality_check                                                                                           0
# entropy                                                                                                      0
# exposed_hydrophobics                                                                                   1989.28
# exposed_polars                                                                                         907.378
# exposed_total                                                                                          2896.66
# fa_atr                                                                                                -760.924
# fa_atr_monomer                                                                                        -139.376
# fa_dun_dev                                                                                               5.772
# fa_dun_monomer                                                                                               0
# fa_dun_rot                                                                                              88.381
# fa_dun_semi                                                                                            127.034
# fa_elec                                                                                               -331.972
# fa_elec_monomer                                                                                        -70.755
# fa_intra_atr_xover4                                                                                    -52.027
# fa_intra_elec                                                                                           -20.06
# fa_intra_rep_monomer                                                                                         0
# fa_intra_rep_xover4                                                                                     20.007
# fa_intra_sol_xover4                                                                                     39.465
# fa_intra_sol_xover4_monomer                                                                              9.476
# fa_rep                                                                                                  103.87
# fa_rep_monomer                                                                                          12.464
# fa_sol                                                                                                 664.102
# fa_sol_monomer                                                                                          156.38
# fxn_exposed_is_np                                                                                        0.687
# fxn_np_chain1_buried_approx                                                                              0.532
# fxn_np_chain2_buried_approx                                                                              0.268
# gen_bonded                                                                                                   0
# hbond_E_fraction                                                                                         0.082
# hbond_bb_sc                                                                                              -2.07
# hbond_bb_sc_monomer                                                                                     -1.197
# hbond_lr_bb                                                                                                  0
# hbond_lr_bb_monomer                                                                                          0
# hbond_per_res                                                                                                0
# hbond_sc                                                                                               -37.941
# hbond_sc_monomer                                                                                        -4.817
# hbond_sr_bb                                                                                           -127.985
# hbond_sr_bb_monomer                                                                                    -30.831
# hbonds_int                                                                                                   7
# helix_sc                                                                                                  0.92
# holes                                                                                                    2.046
# hxl_tors                                                                                                 8.851
# interface_averageDegree_chA                                                                                9.4
# interface_averageDegree_chB                                                                                9.4
# interface_buried_sasa                                                                                  2567.33
# interface_contactcount                                                                                     172
# interface_fxn_hydrophobic                                                                                0.824
# interface_hbonds                                                                                             7
# interface_holes                                                                                         -0.704
# interface_hydrophobic_sasa                                                                             2115.63
# interface_polar_sasa                                                                                   451.699
# interface_salt_bridges                                                                                       2
# interface_sc                                                                                             0.738
# interface_sc_int_area                                                                                  1708.09
# interface_unsat_hbond1                                                                                     911
# interface_unsat_hbond2                                                                                       1
# lk_ball                                                                                                349.971
# lk_ball_bridge                                                                                          -0.735
# lk_ball_bridge_uncpl                                                                                    -4.938
# lk_ball_iso                                                                                           -346.442
# lk_ball_wtd_monomer                                                                                          0
# loop_sc                                                                                                  0.896
# mean_dslf                                                                                                    0
# mismatch_probability                                                                                      0.03
# mutations                                                                                                    0
# new_buns_all_heavy                                                                                           2
# new_buns_bb_heavy                                                                                            1
# new_buns_nonheavy                                                                                            2
# new_buns_sc_heavy                                                                                            1
# np_chain1_exposed_approx                                                                               931.467
# np_chain2_exposed_approx                                                                               2886.59
# nres_all                                                                                                   119
# nres_int                                                                                                    88
# omega                                                                                                    7.778
# omega_monomer                                                                                            0.794
# one_core_each                                                                                                0
# p_aa_pp                                                                                                -22.364
# p_aa_pp_monomer                                                                                         -7.156
# packable                                                                                                 0.613
# packstat                                                                                                 0.543
# per_residue_energy_int                                                                                  -3.406
# percent_core_SASA                                                                                            0
# percent_core_SCN                                                                                             0
# pro_close                                                                                                1.339
# rama_prepro                                                                                              19.02
# rama_prepro_monomer                                                                                      4.358
# ref                                                                                                    -88.838
# ref_monomer                                                                                            -16.503
# res_count_core_SASA                                                                                          0
# res_count_core_SCN                                                                                           0
# rmsdA                                                                                                        0
# rmsdB                                                                                                        0
# rmsdcomplex                                                                                                  0
# sc_value                                                                                                 0.738
# side1_normalized                                                                                        -3.553
# side1_score                                                                                            -99.491
# side2_normalized                                                                                        -3.337
# side2_score                                                                                           -200.213
# ss_contributes_core                                                                                          0
# ss_sc                                                                                                    0.896
# sspred_chainA                                                                                                1
# total_score_monomer                                                                                    -48.399
# two_core_each                                                                                                0
# uhb                                                                                                          3
# uhb2                                                                                                         1
# unsat_hbond2_monomer                                                                                         1
# yhh_planarity_monomer                                                                                        0
# average_res_energy_IA                                                                                 -3.40572
# cross_interface_energy_IA                                                                           -0.0398013
# cross_interface_hbonds_IA                                                                                    7
# delta_unsat_hbonds_IA                                                                                        5
# hbond_energy_IA                                                                                       -7.68819
# interface_delta_sasa_IA                                                                             -0.0365701
# interface_hydrophobic_sasa_IA                                                                          1976.47
# interface_polar_sasa_IA                                                                                 590.86
# pymol_interface_selection_IA   select ZCON_37_N3_C1_2_interface, /ZCON_37_N3_C1_2//B/92+93+94+95+96+97+98+9...
# separated_interface_energy_IA                                                                         -93.8877
# total_res_IA                                                                                                88
# total_sasa_IA                                                                                          7027.69
# full_name                                                              testing_out/grouped/ZCON_37_N3_C1_2.pdb
# seq
#
# description                                                   ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD  \
# total_score                                                                                           -309.759
# AlaCount                                                                                                     2
# NetCharge_binder                                                                                            -1
# NetCharge_target                                                                                             6
# buried_minus_exposed                                                                                   6191.06
# buried_np                                                                                              9968.53
# buried_over_exposed                                                                                      2.639
# cart_bonded_monomer                                                                                          0
# cavity_volume                                                                                           51.334
# complex_normalized                                                                                      -2.868
# contact_all                                                                                                224
# contact_core_SASA                                                                                          224
# contact_core_SCN                                                                                           224
# dG_cross                                                                                              -112.076
# dG_cross/dSASAx100                                                                                      -4.301
# dG_separated                                                                                           -97.317
# dG_separated/dSASAx100                                                                                  -3.735
# dSASA_hphobic                                                                                          2153.42
# dSASA_int                                                                                              2605.61
# dSASA_polar                                                                                            452.191
# degree                                                                                                  10.012
# degree_core_SASA                                                                                        10.012
# degree_core_SCN                                                                                         10.012
# delta_unsatHbonds                                                                                            0
# des_res_chA                                                                                                 21
# des_res_chB                                                                                                 21
# dslf_fa13                                                                                                    0
# dslf_fa13_monomer                                                                                            0
# dslf_quality_check                                                                                           0
# entropy                                                                                                      0
# exposed_hydrophobics                                                                                   3777.47
# exposed_polars                                                                                         2478.05
# exposed_total                                                                                          6255.52
# fa_atr                                                                                                -696.037
# fa_atr_monomer                                                                                        -477.039
# fa_dun_dev                                                                                               7.231
# fa_dun_monomer                                                                                               0
# fa_dun_rot                                                                                              85.957
# fa_dun_semi                                                                                             79.563
# fa_elec                                                                                               -291.014
# fa_elec_monomer                                                                                       -215.421
# fa_intra_atr_xover4                                                                                    -47.221
# fa_intra_elec                                                                                           -8.552
# fa_intra_rep_monomer                                                                                         0
# fa_intra_rep_xover4                                                                                      16.31
# fa_intra_sol_xover4                                                                                     30.725
# fa_intra_sol_xover4_monomer                                                                             23.078
# fa_rep                                                                                                  67.092
# fa_rep_monomer                                                                                          41.838
# fa_sol                                                                                                 561.018
# fa_sol_monomer                                                                                          422.79
# fxn_exposed_is_np                                                                                        0.604
# fxn_np_chain1_buried_approx                                                                              0.289
# fxn_np_chain2_buried_approx                                                                              0.505
# gen_bonded                                                                                                   0
# hbond_E_fraction                                                                                         0.103
# hbond_bb_sc                                                                                                  0
# hbond_bb_sc_monomer                                                                                          0
# hbond_lr_bb                                                                                                  0
# hbond_lr_bb_monomer                                                                                          0
# hbond_per_res                                                                                                0
# hbond_sc                                                                                               -39.354
# hbond_sc_monomer                                                                                       -25.705
# hbond_sr_bb                                                                                           -122.455
# hbond_sr_bb_monomer                                                                                    -91.696
# hbonds_int                                                                                                   6
# helix_sc                                                                                                 0.766
# holes                                                                                                    0.346
# hxl_tors                                                                                                24.348
# interface_averageDegree_chA                                                                              9.151
# interface_averageDegree_chB                                                                              9.151
# interface_buried_sasa                                                                                  2605.61
# interface_contactcount                                                                                     230
# interface_fxn_hydrophobic                                                                                0.838
# interface_hbonds                                                                                             6
# interface_holes                                                                                         -1.095
# interface_hydrophobic_sasa                                                                             2184.67
# interface_polar_sasa                                                                                   420.938
# interface_salt_bridges                                                                                       1
# interface_sc                                                                                             0.799
# interface_sc_int_area                                                                                  1520.44
# interface_unsat_hbond1                                                                                     911
# interface_unsat_hbond2                                                                                       0
# lk_ball                                                                                                305.275
# lk_ball_bridge                                                                                           -0.41
# lk_ball_bridge_uncpl                                                                                    -2.828
# lk_ball_iso                                                                                            -306.52
# lk_ball_wtd_monomer                                                                                          0
# loop_sc                                                                                                  0.776
# mean_dslf                                                                                                    0
# mismatch_probability                                                                                      0.18
# mutations                                                                                                    0
# new_buns_all_heavy                                                                                           0
# new_buns_bb_heavy                                                                                            0
# new_buns_nonheavy                                                                                            0
# new_buns_sc_heavy                                                                                            0
# np_chain1_exposed_approx                                                                               2685.14
# np_chain2_exposed_approx                                                                               1070.04
# nres_all                                                                                                   108
# nres_int                                                                                                    75
# omega                                                                                                   64.633
# omega_monomer                                                                                           63.546
# one_core_each                                                                                                1
# p_aa_pp                                                                                                -12.701
# p_aa_pp_monomer                                                                                         -9.613
# packable                                                                                                 0.561
# packstat                                                                                                 0.577
# per_residue_energy_int                                                                                  -3.027
# percent_core_SASA                                                                                        0.086
# percent_core_SCN                                                                                         0.173
# pro_close                                                                                                    0
# rama_prepro                                                                                              32.76
# rama_prepro_monomer                                                                                     27.606
# ref                                                                                                    -57.579
# ref_monomer                                                                                            -43.208
# res_count_core_SASA                                                                                          7
# res_count_core_SCN                                                                                          14
# rmsdA                                                                                                        0
# rmsdB                                                                                                        0
# rmsdcomplex                                                                                                  0
# sc_value                                                                                                 0.799
# side1_normalized                                                                                        -2.913
# side1_score                                                                                           -142.744
# side2_normalized                                                                                        -3.242
# side2_score                                                                                            -84.283
# ss_contributes_core                                                                                          1
# ss_sc                                                                                                    0.767
# sspred_chainA                                                                                            0.938
# total_score_monomer                                                                                   -166.716
# two_core_each                                                                                                1
# uhb                                                                                                          0
# uhb2                                                                                                         0
# unsat_hbond2_monomer                                                                                         2
# yhh_planarity_monomer                                                                                        0
# average_res_energy_IA                                                                                 -3.02702
# cross_interface_energy_IA                                                                           -0.0430132
# cross_interface_hbonds_IA                                                                                    6
# delta_unsat_hbonds_IA                                                                                        0
# hbond_energy_IA                                                                                       -10.0468
# interface_delta_sasa_IA                                                                              -0.037349
# interface_hydrophobic_sasa_IA                                                                          2153.42
# interface_polar_sasa_IA                                                                                452.191
# pymol_interface_selection_IA   select ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD_interface, /ZCON_37_...
# separated_interface_energy_IA                                                                         -97.3169
# total_res_IA                                                                                                75
# total_sasa_IA                                                                                          6712.25
# full_name                             testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.pdb
# seq
#
# description                                            ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi  \
# total_score                                                                                           -309.759
# AlaCount                                                                                                     2
# NetCharge_binder                                                                                             6
# NetCharge_target                                                                                            -1
# buried_minus_exposed                                                                                   188.247
# buried_np                                                                                              2350.62
# buried_over_exposed                                                                                      1.087
# cart_bonded_monomer                                                                                          0
# cavity_volume                                                                                                0
# complex_normalized                                                                                      -2.868
# contact_all                                                                                                  7
# contact_core_SASA                                                                                            7
# contact_core_SCN                                                                                             7
# dG_cross                                                                                              -112.076
# dG_cross/dSASAx100                                                                                      -4.301
# dG_separated                                                                                           -97.317
# dG_separated/dSASAx100                                                                                  -3.735
# dSASA_hphobic                                                                                          2153.42
# dSASA_int                                                                                              2605.61
# dSASA_polar                                                                                            452.191
# degree                                                                                                   8.259
# degree_core_SASA                                                                                         8.259
# degree_core_SCN                                                                                          8.259
# delta_unsatHbonds                                                                                            0
# des_res_chA                                                                                                 21
# des_res_chB                                                                                                 21
# dslf_fa13                                                                                                    0
# dslf_fa13_monomer                                                                                            0
# dslf_quality_check                                                                                           0
# entropy                                                                                                      0
# exposed_hydrophobics                                                                                   2162.38
# exposed_polars                                                                                         899.961
# exposed_total                                                                                          3062.34
# fa_atr                                                                                                -696.037
# fa_atr_monomer                                                                                        -119.799
# fa_dun_dev                                                                                               7.231
# fa_dun_monomer                                                                                               0
# fa_dun_rot                                                                                              85.957
# fa_dun_semi                                                                                             79.563
# fa_elec                                                                                               -291.014
# fa_elec_monomer                                                                                        -62.368
# fa_intra_atr_xover4                                                                                    -47.221
# fa_intra_elec                                                                                           -8.552
# fa_intra_rep_monomer                                                                                         0
# fa_intra_rep_xover4                                                                                      16.31
# fa_intra_sol_xover4                                                                                     30.725
# fa_intra_sol_xover4_monomer                                                                              7.646
# fa_rep                                                                                                  67.092
# fa_rep_monomer                                                                                           9.119
# fa_sol                                                                                                 561.018
# fa_sol_monomer                                                                                         139.905
# fxn_exposed_is_np                                                                                        0.706
# fxn_np_chain1_buried_approx                                                                              0.505
# fxn_np_chain2_buried_approx                                                                              0.289
# gen_bonded                                                                                                   0
# hbond_E_fraction                                                                                         0.103
# hbond_bb_sc                                                                                                  0
# hbond_bb_sc_monomer                                                                                          0
# hbond_lr_bb                                                                                                  0
# hbond_lr_bb_monomer                                                                                          0
# hbond_per_res                                                                                                0
# hbond_sc                                                                                               -39.354
# hbond_sc_monomer                                                                                        -3.603
# hbond_sr_bb                                                                                           -122.455
# hbond_sr_bb_monomer                                                                                    -30.759
# hbonds_int                                                                                                   6
# helix_sc                                                                                                     0
# holes                                                                                                    2.735
# hxl_tors                                                                                                24.348
# interface_averageDegree_chA                                                                              9.151
# interface_averageDegree_chB                                                                              9.151
# interface_buried_sasa                                                                                  2605.61
# interface_contactcount                                                                                     230
# interface_fxn_hydrophobic                                                                                0.838
# interface_hbonds                                                                                             6
# interface_holes                                                                                         -1.661
# interface_hydrophobic_sasa                                                                             2184.67
# interface_polar_sasa                                                                                   420.938
# interface_salt_bridges                                                                                       1
# interface_sc                                                                                             0.799
# interface_sc_int_area                                                                                  1520.44
# interface_unsat_hbond1                                                                                     911
# interface_unsat_hbond2                                                                                       0
# lk_ball                                                                                                305.275
# lk_ball_bridge                                                                                           -0.41
# lk_ball_bridge_uncpl                                                                                    -2.828
# lk_ball_iso                                                                                            -306.52
# lk_ball_wtd_monomer                                                                                          0
# loop_sc                                                                                                  0.863
# mean_dslf                                                                                                    0
# mismatch_probability                                                                                     0.043
# mutations                                                                                                    0
# new_buns_all_heavy                                                                                           0
# new_buns_bb_heavy                                                                                            0
# new_buns_nonheavy                                                                                            0
# new_buns_sc_heavy                                                                                            0
# np_chain1_exposed_approx                                                                               1070.04
# np_chain2_exposed_approx                                                                               2685.14
# nres_all                                                                                                   108
# nres_int                                                                                                    75
# omega                                                                                                   64.633
# omega_monomer                                                                                            1.087
# one_core_each                                                                                                0
# p_aa_pp                                                                                                -12.701
# p_aa_pp_monomer                                                                                         -3.088
# packable                                                                                                 0.525
# packstat                                                                                                 0.549
# per_residue_energy_int                                                                                  -3.027
# percent_core_SASA                                                                                            0
# percent_core_SCN                                                                                             0
# pro_close                                                                                                    0
# rama_prepro                                                                                              32.76
# rama_prepro_monomer                                                                                      5.154
# ref                                                                                                    -57.579
# ref_monomer                                                                                            -14.371
# res_count_core_SASA                                                                                          0
# res_count_core_SCN                                                                                           0
# rmsdA                                                                                                        0
# rmsdB                                                                                                        0
# rmsdcomplex                                                                                                  0
# sc_value                                                                                                 0.799
# side1_normalized                                                                                        -2.913
# ...
# buried_over_exposed                                                                                       2.19
# cart_bonded_monomer                                                                                          0
# cavity_volume                                                                                                0
# complex_normalized                                                                                      -2.884
# contact_all                                                                                                124
# contact_core_SASA                                                                                          124
# contact_core_SCN                                                                                           124
# dG_cross                                                                                              -114.047
# dG_cross/dSASAx100                                                                                      -4.304
# dG_separated                                                                                           -93.646
# dG_separated/dSASAx100                                                                                  -3.534
# dSASA_hphobic                                                                                          1895.18
# dSASA_int                                                                                              2649.64
# dSASA_polar                                                                                            754.458
# degree                                                                                                   9.556
# degree_core_SASA                                                                                         9.556
# degree_core_SCN                                                                                          9.556
# delta_unsatHbonds                                                                                            0
# des_res_chA                                                                                                 29
# des_res_chB                                                                                                 29
# dslf_fa13                                                                                                    0
# dslf_fa13_monomer                                                                                            0
# dslf_quality_check                                                                                           0
# entropy                                                                                                      0
# exposed_hydrophobics                                                                                    2850.5
# exposed_polars                                                                                         1877.89
# exposed_total                                                                                          4728.39
# fa_atr                                                                                                 -696.15
# fa_atr_monomer                                                                                        -299.657
# fa_dun_dev                                                                                               7.464
# fa_dun_monomer                                                                                               0
# fa_dun_rot                                                                                              86.554
# fa_dun_semi                                                                                             79.563
# fa_elec                                                                                               -290.825
# fa_elec_monomer                                                                                       -138.645
# fa_intra_atr_xover4                                                                                    -47.192
# fa_intra_elec                                                                                             -6.6
# fa_intra_rep_monomer                                                                                         0
# fa_intra_rep_xover4                                                                                     16.316
# fa_intra_sol_xover4                                                                                      30.63
# fa_intra_sol_xover4_monomer                                                                             16.295
# fa_rep                                                                                                  67.093
# fa_rep_monomer                                                                                          25.396
# fa_sol                                                                                                 561.449
# fa_sol_monomer                                                                                         279.664
# fxn_exposed_is_np                                                                                        0.603
# fxn_np_chain1_buried_approx                                                                              0.348
# fxn_np_chain2_buried_approx                                                                              0.343
# gen_bonded                                                                                                   0
# hbond_E_fraction                                                                                         0.197
# hbond_bb_sc                                                                                                  0
# hbond_bb_sc_monomer                                                                                          0
# hbond_lr_bb                                                                                                  0
# hbond_lr_bb_monomer                                                                                          0
# hbond_per_res                                                                                                0
# hbond_sc                                                                                               -39.354
# hbond_sc_monomer                                                                                       -13.139
# hbond_sr_bb                                                                                           -122.455
# hbond_sr_bb_monomer                                                                                    -61.194
# hbonds_int                                                                                                  13
# helix_sc                                                                                                 0.824
# holes                                                                                                    0.965
# hxl_tors                                                                                                24.348
# interface_averageDegree_chA                                                                              9.571
# interface_averageDegree_chB                                                                              9.571
# interface_buried_sasa                                                                                  2649.64
# interface_contactcount                                                                                     253
# interface_fxn_hydrophobic                                                                                0.748
# interface_hbonds                                                                                            13
# interface_holes                                                                                         -1.511
# interface_hydrophobic_sasa                                                                             1981.25
# interface_polar_sasa                                                                                   668.384
# interface_salt_bridges                                                                                       2
# interface_sc                                                                                             0.747
# interface_sc_int_area                                                                                  1634.63
# interface_unsat_hbond1                                                                                     911
# interface_unsat_hbond2                                                                                       0
# lk_ball                                                                                                305.225
# lk_ball_bridge                                                                                           -0.41
# lk_ball_bridge_uncpl                                                                                    -2.828
# lk_ball_iso                                                                                            -306.66
# lk_ball_wtd_monomer                                                                                          0
# loop_sc                                                                                                  0.831
# mean_dslf                                                                                                    0
# mismatch_probability                                                                                      0.21
# mutations                                                                                                    0
# new_buns_all_heavy                                                                                           0
# new_buns_bb_heavy                                                                                            0
# new_buns_nonheavy                                                                                            0
# new_buns_sc_heavy                                                                                            0
# np_chain1_exposed_approx                                                                               1859.87
# np_chain2_exposed_approx                                                                               1896.67
# nres_all                                                                                                   108
# nres_int                                                                                                    83
# omega                                                                                                   54.092
# omega_monomer                                                                                           23.825
# one_core_each                                                                                                1
# p_aa_pp                                                                                                -12.454
# p_aa_pp_monomer                                                                                         -4.837
# packable                                                                                                 0.507
# packstat                                                                                                 0.578
# per_residue_energy_int                                                                                  -3.138
# percent_core_SASA                                                                                            0
# percent_core_SCN                                                                                         0.093
# pro_close                                                                                                    0
# rama_prepro                                                                                              38.27
# rama_prepro_monomer                                                                                      20.21
# ref                                                                                                    -57.579
# ref_monomer                                                                                            -31.759
# res_count_core_SASA                                                                                          0
# res_count_core_SCN                                                                                           5
# rmsdA                                                                                                        0
# rmsdB                                                                                                        0
# rmsdcomplex                                                                                                  0
# sc_value                                                                                                 0.747
# side1_normalized                                                                                        -2.887
# side1_score                                                                                           -124.156
# side2_normalized                                                                                        -3.408
# side2_score                                                                                           -136.332
# ss_contributes_core                                                                                          1
# ss_sc                                                                                                    0.825
# sspred_chainA                                                                                            0.944
# total_score_monomer                                                                                    -99.501
# two_core_each                                                                                              0.5
# uhb                                                                                                          0
# uhb2                                                                                                         0
# unsat_hbond2_monomer                                                                                         1
# yhh_planarity_monomer                                                                                        0
# average_res_energy_IA                                                                                 -3.13841
# cross_interface_energy_IA                                                                           -0.0430425
# cross_interface_hbonds_IA                                                                                   13
# delta_unsat_hbonds_IA                                                                                        0
# hbond_energy_IA                                                                                       -18.4119
# interface_delta_sasa_IA                                                                             -0.0353428
# interface_hydrophobic_sasa_IA                                                                          1895.18
# interface_polar_sasa_IA                                                                                754.458
# pymol_interface_selection_IA   select ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD_interface, /ZCON_37_...
# separated_interface_energy_IA                                                                         -93.6456
# total_res_IA                                                                                                83
# total_sasa_IA                                                                                          6709.97
# full_name                             testing_out/grouped/ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD.pdb
# seq

# %%
scores_sasa = [col for col in scores.columns if "sasa" in col.lower()]
scores_sasa
with pd.option_context("display.max_rows", 1000, "display.max_colwidth", 80, "display.width", 50):
    display(scores[scores_sasa].transpose())
# Out:
# description                    ZCON_37_N3_C1_2  \
# contact_core_SASA                     32.00000
# dG_cross/dSASAx100                    -3.98000
# dG_separated/dSASAx100                -3.65700
# dSASA_hphobic                       1976.47400
# dSASA_int                           2567.33300
# dSASA_polar                          590.86000
# degree_core_SASA                       8.14300
# interface_buried_sasa               2567.33300
# interface_hydrophobic_sasa          2115.63400
# interface_polar_sasa                 451.69900
# percent_core_SASA                      0.00000
# res_count_core_SASA                    0.00000
# interface_delta_sasa_IA               -0.03657
# interface_hydrophobic_sasa_IA       1976.47000
# interface_polar_sasa_IA              590.86000
# total_sasa_IA                       7027.69000
#
# description                    ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD  \
# contact_core_SASA                                                    224.000000
# dG_cross/dSASAx100                                                    -4.301000
# dG_separated/dSASAx100                                                -3.735000
# dSASA_hphobic                                                       2153.419000
# dSASA_int                                                           2605.610000
# dSASA_polar                                                          452.191000
# degree_core_SASA                                                      10.012000
# interface_buried_sasa                                               2605.610000
# interface_hydrophobic_sasa                                          2184.672000
# interface_polar_sasa                                                 420.938000
# percent_core_SASA                                                      0.086000
# res_count_core_SASA                                                    7.000000
# interface_delta_sasa_IA                                               -0.037349
# interface_hydrophobic_sasa_IA                                       2153.420000
# interface_polar_sasa_IA                                              452.191000
# total_sasa_IA                                                       6712.250000
#
# description                    ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi  \
# contact_core_SASA                                                             7.000000
# dG_cross/dSASAx100                                                           -4.301000
# dG_separated/dSASAx100                                                       -3.735000
# dSASA_hphobic                                                              2153.419000
# dSASA_int                                                                  2605.610000
# dSASA_polar                                                                 452.191000
# degree_core_SASA                                                              8.259000
# interface_buried_sasa                                                      2605.610000
# interface_hydrophobic_sasa                                                 2184.672000
# interface_polar_sasa                                                        420.938000
# percent_core_SASA                                                             0.000000
# res_count_core_SASA                                                           0.000000
# interface_delta_sasa_IA                                                      -0.037349
# interface_hydrophobic_sasa_IA                                              2153.420000
# interface_polar_sasa_IA                                                     452.191000
# total_sasa_IA                                                              6712.250000
#
# description                    ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD
# contact_core_SASA                                                    124.000000
# dG_cross/dSASAx100                                                    -4.304000
# dG_separated/dSASAx100                                                -3.534000
# dSASA_hphobic                                                       1895.179000
# dSASA_int                                                           2649.636000
# dSASA_polar                                                          754.458000
# degree_core_SASA                                                       9.556000
# interface_buried_sasa                                               2649.636000
# interface_hydrophobic_sasa                                          1981.252000
# interface_polar_sasa                                                 668.384000
# percent_core_SASA                                                      0.000000
# res_count_core_SASA                                                    0.000000
# interface_delta_sasa_IA                                               -0.035343
# interface_hydrophobic_sasa_IA                                       1895.180000
# interface_polar_sasa_IA                                              754.458000
# total_sasa_IA                                                       6709.970000

# %%
scores_hbond = [col for col in scores.columns if "loop_sc" in col.lower()]
scores_hbond
with pd.option_context("display.max_rows", 1000, "display.max_colwidth", 80, "display.width", 50):
    display(scores[scores_hbond].transpose())
# Out:
# description  ZCON_37_N3_C1_2  \
# loop_sc                0.896
#
# description  ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD  \
# loop_sc                                                 0.776
#
# description  ZCON_37_3+1__numH4__from-22.25__to17.45__grC-ABD.nosegi  \
# loop_sc                                                        0.863
#
# description  ZCON_37_3+1__numH4__from-22.25__to17.45__grAB-CD
# loop_sc                                                 0.831

# %%
truncator.score_interface("data/ZCON_37_N3_C1_2.pdb",
                script_name="truncator/xml/04_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_select.xml",
                out_dir="testing_out/grouped", tee=False, test_run=True)
# Out:
# /software/rosetta/latest/bin/rosetta_scripts     -parser:protocol truncator/xml/04_FD_FR_and_scoring_benchmark_v3_digs_updated_schema_BUNS3_IA_select.xml -s data/ZCON_37_N3_C1_2.pdb     -out:file:scorefile  testing_out/grouped/ZCON_37_N3_C1_2.sc     -out:file:o  testing_out/grouped/ZCON_37_N3_C1_2.pdb     -print_pymol_selection 0     -beta     -in:file:fullatom     -renumber_pdb 1     -overwrite     -out:no_nstruct_label     -holes:dalphaball truncator/scripts/DAlphaBall.gcc     > testing_out/grouped/ZCON_37_N3_C1_2.log
# Saving to: testing_out/grouped/ZCON_37_N3_C1_2_IA.sc
# 'testing_out/grouped/ZCON_37_N3_C1_2_IA.sc'

# %%
scores = truncator.read_score_files(['testing_out/grouped/ZCON_37_N3_C1_2_IA.sc'], skiprows=False, load_seq=False).set_index('description')
with pd.option_context("display.max_rows", 1000, "display.max_colwidth", 80, "display.width", 50):
    display(scores.transpose())
# Out:
# description                                                                                    ZCON_37_N3_C1_2
# total_score                                                                                           -360.706
# NetCharge_A                                                                                                 -3
# NetCharge_B                                                                                                 -6
# VirtualRootMover_root                                                                                      120
# cart_bonded_monomer                                                                                          0
# cavity_volume                                                                                                0
# complex_normalized                                                                                      -3.031
# dG_cross                                                                                              -102.183
# dG_cross/dSASAx100                                                                                       -3.98
# dG_separated                                                                                           -93.888
# dG_separated/dSASAx100                                                                                  -3.657
# dSASA_hphobic                                                                                          1976.47
# dSASA_int                                                                                              2567.33
# dSASA_polar                                                                                             590.86
# delta_unsatHbonds                                                                                            5
# dslf_fa13                                                                                                    0
# dslf_fa13_monomer                                                                                            0
# exposed_hydrophobics                                                                                   1989.28
# exposed_polars                                                                                         907.378
# exposed_total                                                                                          2896.66
# fa_atr                                                                                                -760.924
# fa_atr_monomer                                                                                        -139.376
# fa_dun_dev                                                                                               5.772
# fa_dun_monomer                                                                                               0
# fa_dun_rot                                                                                              88.381
# fa_dun_semi                                                                                            127.034
# fa_elec                                                                                               -331.972
# fa_elec_monomer                                                                                        -70.755
# fa_intra_atr_xover4                                                                                    -52.027
# fa_intra_elec                                                                                           -20.06
# fa_intra_rep_monomer                                                                                         0
# fa_intra_rep_xover4                                                                                     20.007
# fa_intra_sol_xover4                                                                                     39.465
# fa_intra_sol_xover4_monomer                                                                              9.476
# fa_rep                                                                                                  103.87
# fa_rep_monomer                                                                                          12.464
# fa_sol                                                                                                 664.102
# fa_sol_monomer                                                                                          156.38
# gen_bonded                                                                                                   0
# hbond_E_fraction                                                                                         0.082
# hbond_bb_sc                                                                                              -2.07
# hbond_bb_sc_monomer                                                                                     -1.197
# hbond_lr_bb                                                                                                  0
# hbond_lr_bb_monomer                                                                                          0
# hbond_sc                                                                                               -37.941
# hbond_sc_monomer                                                                                        -4.817
# hbond_sr_bb                                                                                           -127.985
# hbond_sr_bb_monomer                                                                                    -30.831
# hbonds_int                                                                                                   7
# helix_sc                                                                                                  0.92
# hxl_tors                                                                                                 8.851
# interface_buried_sasa                                                                                  2567.33
# interface_contactcount                                                                                     172
# interface_hbonds                                                                                             7
# interface_holes                                                                                         -0.704
# interface_hydrophobic_sasa                                                                             2115.63
# interface_polar_sasa                                                                                   451.699
# interface_salt_bridges                                                                                       2
# interface_sc                                                                                             0.738
# interface_sc_int_area                                                                                  1708.09
# interface_unsat_hbond2                                                                                       1
# lk_ball                                                                                                349.971
# lk_ball_bridge                                                                                          -0.735
# lk_ball_bridge_uncpl                                                                                    -4.938
# lk_ball_iso                                                                                           -346.442
# loop_sc                                                                                                  0.896
# new_buns_all_heavy                                                                                           2
# new_buns_bb_heavy                                                                                            1
# new_buns_nonheavy                                                                                            2
# new_buns_sc_heavy                                                                                            1
# nres_all                                                                                                   119
# nres_int                                                                                                    88
# omega                                                                                                    7.778
# p_aa_pp                                                                                                -22.364
# packstat                                                                                                 0.578
# per_residue_energy_int                                                                                  -3.406
# pro_close                                                                                                1.339
# rama_prepro                                                                                              19.02
# ref                                                                                                    -88.838
# sc_value                                                                                                 0.738
# side1_normalized                                                                                        -3.553
# side1_score                                                                                            -99.491
# side2_normalized                                                                                        -3.337
# side2_score                                                                                           -200.213
# ss_sc                                                                                                    0.896
# total_sasa_A                                                                                           2896.66
# total_sasa_AB                                                                                          7027.69
# total_sasa_B                                                                                           6698.36
# total_sasa_hydrophobic_A                                                                               1989.28
# total_sasa_hydrophobic_AB                                                                              3891.95
# total_sasa_hydrophobic_B                                                                                4018.3
# total_sasa_polar_A                                                                                     907.378
# total_sasa_polar_AB                                                                                    3209.62
# total_sasa_polar_B                                                                                     2753.95
# total_score_monomer                                                                                    -48.399
# uhb                                                                                                          3
# uhb2                                                                                                         1
# average_res_energy_IA                                                                                 -3.40572
# cross_interface_energy_IA                                                                           -0.0398013
# cross_interface_hbonds_IA                                                                                    7
# delta_unsat_hbonds_IA                                                                                        5
# hbond_energy_IA                                                                                       -7.68819
# interface_delta_sasa_IA                                                                             -0.0365701
# interface_hydrophobic_sasa_IA                                                                          1976.47
# interface_polar_sasa_IA                                                                                 590.86
# pymol_interface_selection_IA   select ZCON_37_N3_C1_2_interface, /ZCON_37_N3_C1_2//B/92+93+94+95+96+97+98+9...
# separated_interface_energy_IA                                                                         -93.8877
# total_res_IA                                                                                                88
# total_sasa_IA                                                                                          7027.69
# full_name                                                                                                 None
# seq

# %%
interesting_cols = """
interface_averageDegree_chA
interface_averageDegree_chB
interface_buried_sasa
interface_contactcount
interface_fxn_hydrophobic
interface_hbonds
interface_holes
interface_hydrophobic_sasa
interface_polar_sasa
interface_salt_bridges
interface_sc
interface_sc_int_area
interface_unsat_hbond1
interface_unsat_hbond2
cross_interface_energy_IA
cross_interface_hbonds_IA
delta_unsat_hbonds_IA
hbond_energy_IA
interface_delta_sasa_IA
interface_hydrophobic_sasa_IA
interface_polar_sasa_IA
exposed_hydrophobics
exposed_polars
exposed_total
""".split()
#print("\n".join(list(df.columns)))
df[interesting_cols].transpose()

# %%
import os
import subprocess, sys
os.system("echo TEST")
# !ls -l
# Out:
# total 690
# -rw-r--r-- 1 ajasja baker 256387 Jan 17 16:07 00b_test_dask.ipynb
# -rw-r--r-- 1 ajasja baker 181564 Jan 25 10:46 00_cutting_develop.ipynb
# -rw-r--r-- 1 ajasja baker  43279 Jan  7 12:11 01_score_interface_develop.ipynb
# -rw-r--r-- 1 ajasja baker   5778 Jan 25 10:55 02_looping_develop.ipynb
# -rw-r--r-- 1 ajasja baker  58810 Jan 24 10:20 80-test-pyrosetta.ipynb
# -rw-r--r-- 1 ajasja baker   6043 Oct 18 14:46 80-test-pyrosetta.xml
# -rw-r--r-- 1 ajasja baker  18246 Jan 23 15:57 90_Copy_scaffolds.ipynb
# -rw-r--r-- 1 ajasja baker   7319 Jan 17 10:52 dask-worker.err
# -rw-r--r-- 1 ajasja baker   1260 Jan 17 10:53 dask-worker.out
# drwxr-xr-x 2 ajasja baker      6 Jan 14 13:38 data
# -rw-r--r-- 1 ajasja baker      0 Jan 17 10:42 global.lock
# -rw-r--r-- 1 ajasja baker  25425 Jan 23 15:09 Interface_analyser.ipynb
# -rw-r--r-- 1 ajasja baker 176536 Jan 24 16:40 layer_design_input.pdb
# -rw-r--r-- 1 ajasja baker    609 Jan 24 16:40 layers.py
# drwxr-xr-x 2 ajasja baker     15 Jan 23 15:39 old
# -rw-r--r-- 1 ajasja baker      0 Jan 17 10:42 purge.lock
# -rw-r--r-- 1 ajasja baker     54 Nov 30 14:35 pytest.ini
# -rw-r--r-- 1 ajasja baker    122 Dec  5 14:57 Readme.txt
# -rw-r--r-- 1 ajasja baker    893 Jan 24 17:38 score.sc
# -rw-r--r-- 1 ajasja baker   1709 Dec  7 16:24 setup.py
# drwxr-xr-x 4 ajasja baker     16 Jan 24 15:18 testing_out
# -rw-r--r-- 1 ajasja baker 189978 Jan 24 10:18 test.pdb
# -rw-r--r-- 1 ajasja baker   9603 Jan 24 10:18 test.sc
# drwxr-xr-x 5 ajasja baker     11 Jan  9 12:05 truncator
# -rw-r--r-- 1 ajasja baker  15460 Jan 15 10:18 validate_xml_script.ipynb
# -rw-r--r-- 1 ajasja baker 174878 Jan 24 17:38 ZCON_37_3+1__numH4__from-17.89__to21.81_0001.pdb
# -rw-r--r-- 1 ajasja baker 192145 Jan 25 10:04 ZCON_37_N3_C1_2.pdb

# %%
pd.set_option('display.max_rows', None)
pd.options.display.max_columns=None
df.transpose()

# %%
import dask
from dask_jobqueue import SLURMCluster

cluster = SLURMCluster(cores=1,
                     memory="2GB",
                     queue='interactive',)
cluster.scale(4)

from dask.distributed import Client
client = Client(cluster)
